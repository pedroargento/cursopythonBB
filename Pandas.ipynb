# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
drinks = pd.read_csv('./data/drinks.csv')

type(drinks)
# Out:
# pandas.core.frame.DataFrame

# %%
drinks
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# 12                Bahrain             42               63              7
# 13             Bangladesh              0                0              0
# 14               Barbados            143              173             36
# 15                Belarus            142              373             42
# 16                Belgium            295               84            212
# 17                 Belize            263              114              8
# 18                  Benin             34                4             13
# 19                 Bhutan             23                0              0
# 20                Bolivia            167               41              8
# 21     Bosnia-Herzegovina             76              173              8
# 22               Botswana            173               35             35
# 23                 Brazil            245              145             16
# 24                 Brunei             31                2              1
# 25               Bulgaria            231              252             94
# 26           Burkina Faso             25                7              7
# 27                Burundi             88                0              0
# 28          Cote d'Ivoire             37                1              7
# 29             Cabo Verde            144               56             16
# ..                    ...            ...              ...            ...
# 163              Suriname            128              178              7
# 164             Swaziland             90                2              2
# 165                Sweden            152               60            186
# 166           Switzerland            185              100            280
# 167                 Syria              5               35             16
# 168            Tajikistan              2               15              0
# 169              Thailand             99              258              1
# 170             Macedonia            106               27             86
# 171           Timor-Leste              1                1              4
# 172                  Togo             36                2             19
# 173                 Tonga             36               21              5
# 174     Trinidad & Tobago            197              156              7
# 175               Tunisia             51                3             20
# 176                Turkey             51               22              7
# 177          Turkmenistan             19               71             32
# 178                Tuvalu              6               41              9
# 179                Uganda             45                9              0
# 180               Ukraine            206              237             45
# 181  United Arab Emirates             16              135              5
# 182        United Kingdom            219              126            195
# 183              Tanzania             36                6              1
# 184                   USA            249              158             84
# 185               Uruguay            115               35            220
# 186            Uzbekistan             25              101              8
# 187               Vanuatu             21               18             11
# 188             Venezuela            333              100              3
# 189               Vietnam            111                2              1
# 190                 Yemen              6                0              0
# 191                Zambia             32               19              4
# 192              Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# 3                            12.4        EU
# 4                             5.9        AF
# 5                             4.9       NaN
# 6                             8.3        SA
# 7                             3.8        EU
# 8                            10.4        OC
# 9                             9.7        EU
# 10                            1.3        EU
# 11                            6.3       NaN
# 12                            2.0        AS
# 13                            0.0        AS
# 14                            6.3       NaN
# 15                           14.4        EU
# 16                           10.5        EU
# 17                            6.8       NaN
# 18                            1.1        AF
# 19                            0.4        AS
# 20                            3.8        SA
# 21                            4.6        EU
# 22                            5.4        AF
# 23                            7.2        SA
# 24                            0.6        AS
# 25                           10.3        EU
# 26                            4.3        AF
# 27                            6.3        AF
# 28                            4.0        AF
# 29                            4.0        AF
# ..                            ...       ...
# 163                           5.6        SA
# 164                           4.7        AF
# 165                           7.2        EU
# 166                          10.2        EU
# 167                           1.0        AS
# 168                           0.3        AS
# 169                           6.4        AS
# 170                           3.9        EU
# 171                           0.1        AS
# 172                           1.3        AF
# 173                           1.1        OC
# 174                           6.4       NaN
# 175                           1.3        AF
# 176                           1.4        AS
# 177                           2.2        AS
# 178                           1.0        OC
# 179                           8.3        AF
# 180                           8.9        EU
# 181                           2.8        AS
# 182                          10.4        EU
# 183                           5.7        AF
# 184                           8.7       NaN
# 185                           6.6        SA
# 186                           2.4        AS
# 187                           0.9        OC
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF
#
# [193 rows x 6 columns]

# %%
drinks.shape
# Out:
# (193, 6)

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
# DataFrames são dicionários, onde as colunas são as chaves. 
d = {'a':[1,2], 'b':[3,4]}
pd.DataFrame(d)
# Out:
#    a  b
# 0  1  3
# 1  2  4

# %%
drinks.isnull()
# Out:
#      country  beer_servings  spirit_servings  wine_servings  \
# 0      False          False            False          False
# 1      False          False            False          False
# 2      False          False            False          False
# 3      False          False            False          False
# 4      False          False            False          False
# 5      False          False            False          False
# 6      False          False            False          False
# 7      False          False            False          False
# 8      False          False            False          False
# 9      False          False            False          False
# 10     False          False            False          False
# 11     False          False            False          False
# 12     False          False            False          False
# 13     False          False            False          False
# 14     False          False            False          False
# 15     False          False            False          False
# 16     False          False            False          False
# 17     False          False            False          False
# 18     False          False            False          False
# 19     False          False            False          False
# 20     False          False            False          False
# 21     False          False            False          False
# 22     False          False            False          False
# 23     False          False            False          False
# 24     False          False            False          False
# 25     False          False            False          False
# 26     False          False            False          False
# 27     False          False            False          False
# 28     False          False            False          False
# 29     False          False            False          False
# ..       ...            ...              ...            ...
# 163    False          False            False          False
# 164    False          False            False          False
# 165    False          False            False          False
# 166    False          False            False          False
# 167    False          False            False          False
# 168    False          False            False          False
# 169    False          False            False          False
# 170    False          False            False          False
# 171    False          False            False          False
# 172    False          False            False          False
# 173    False          False            False          False
# 174    False          False            False          False
# 175    False          False            False          False
# 176    False          False            False          False
# 177    False          False            False          False
# 178    False          False            False          False
# 179    False          False            False          False
# 180    False          False            False          False
# 181    False          False            False          False
# 182    False          False            False          False
# 183    False          False            False          False
# 184    False          False            False          False
# 185    False          False            False          False
# 186    False          False            False          False
# 187    False          False            False          False
# 188    False          False            False          False
# 189    False          False            False          False
# 190    False          False            False          False
# 191    False          False            False          False
# 192    False          False            False          False
#
#      total_litres_of_pure_alcohol  continent
# 0                           False      False
# 1                           False      False
# 2                           False      False
# 3                           False      False
# 4                           False      False
# 5                           False       True
# 6                           False      False
# 7                           False      False
# 8                           False      False
# 9                           False      False
# 10                          False      False
# 11                          False       True
# 12                          False      False
# 13                          False      False
# 14                          False       True
# 15                          False      False
# 16                          False      False
# 17                          False       True
# 18                          False      False
# 19                          False      False
# 20                          False      False
# 21                          False      False
# 22                          False      False
# 23                          False      False
# 24                          False      False
# 25                          False      False
# 26                          False      False
# 27                          False      False
# 28                          False      False
# 29                          False      False
# ..                            ...        ...
# 163                         False      False
# 164                         False      False
# 165                         False      False
# 166                         False      False
# 167                         False      False
# 168                         False      False
# 169                         False      False
# 170                         False      False
# 171                         False      False
# 172                         False      False
# 173                         False      False
# 174                         False       True
# 175                         False      False
# 176                         False      False
# 177                         False      False
# 178                         False      False
# 179                         False      False
# 180                         False      False
# 181                         False      False
# 182                         False      False
# 183                         False      False
# 184                         False       True
# 185                         False      False
# 186                         False      False
# 187                         False      False
# 188                         False      False
# 189                         False      False
# 190                         False      False
# 191                         False      False
# 192                         False      False
#
# [193 rows x 6 columns]

# %%
drinks.isnull().sum()
# Out:
# country                          0
# beer_servings                    0
# spirit_servings                  0
# wine_servings                    0
# total_litres_of_pure_alcohol     0
# continent                       23
# dtype: int64

# %%
drinks[drinks['continent'].isnull()]
# Out:
#                           country  beer_servings  spirit_servings  \
# 5               Antigua & Barbuda            102              128
# 11                        Bahamas            122              176
# 14                       Barbados            143              173
# 17                         Belize            263              114
# 32                         Canada            240              122
# 41                     Costa Rica            149               87
# 43                           Cuba             93              137
# 50                       Dominica             52              286
# 51             Dominican Republic            193              147
# 54                    El Salvador             52               69
# 68                        Grenada            199              438
# 69                      Guatemala             53               69
# 73                          Haiti              1              326
# 74                       Honduras             69               98
# 84                        Jamaica             82               97
# 109                        Mexico            238               68
# 122                     Nicaragua             78              118
# 130                        Panama            285              104
# 143             St. Kitts & Nevis            194              205
# 144                     St. Lucia            171              315
# 145  St. Vincent & the Grenadines            120              221
# 174             Trinidad & Tobago            197              156
# 184                           USA            249              158
#
#      wine_servings  total_litres_of_pure_alcohol continent
# 5               45                           4.9       NaN
# 11              51                           6.3       NaN
# 14              36                           6.3       NaN
# 17               8                           6.8       NaN
# 32             100                           8.2       NaN
# 41              11                           4.4       NaN
# 43               5                           4.2       NaN
# 50              26                           6.6       NaN
# 51               9                           6.2       NaN
# 54               2                           2.2       NaN
# 68              28                          11.9       NaN
# 69               2                           2.2       NaN
# 73               1                           5.9       NaN
# 74               2                           3.0       NaN
# 84               9                           3.4       NaN
# 109              5                           5.5       NaN
# 122              1                           3.5       NaN
# 130             18                           7.2       NaN
# 143             32                           7.7       NaN
# 144             71                          10.1       NaN
# 145             11                           6.3       NaN
# 174              7                           6.4       NaN
# 184             84                           8.7       NaN

# %%
# Valores faltando
drinks.dropna()             # Descarta linhas com valores faltando
drinks.fillna(value='NA')   # Substitui valores faltando
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# 12                Bahrain             42               63              7
# 13             Bangladesh              0                0              0
# 14               Barbados            143              173             36
# 15                Belarus            142              373             42
# 16                Belgium            295               84            212
# 17                 Belize            263              114              8
# 18                  Benin             34                4             13
# 19                 Bhutan             23                0              0
# 20                Bolivia            167               41              8
# 21     Bosnia-Herzegovina             76              173              8
# 22               Botswana            173               35             35
# 23                 Brazil            245              145             16
# 24                 Brunei             31                2              1
# 25               Bulgaria            231              252             94
# 26           Burkina Faso             25                7              7
# 27                Burundi             88                0              0
# 28          Cote d'Ivoire             37                1              7
# 29             Cabo Verde            144               56             16
# ..                    ...            ...              ...            ...
# 163              Suriname            128              178              7
# 164             Swaziland             90                2              2
# 165                Sweden            152               60            186
# 166           Switzerland            185              100            280
# 167                 Syria              5               35             16
# 168            Tajikistan              2               15              0
# 169              Thailand             99              258              1
# 170             Macedonia            106               27             86
# 171           Timor-Leste              1                1              4
# 172                  Togo             36                2             19
# 173                 Tonga             36               21              5
# 174     Trinidad & Tobago            197              156              7
# 175               Tunisia             51                3             20
# 176                Turkey             51               22              7
# 177          Turkmenistan             19               71             32
# 178                Tuvalu              6               41              9
# 179                Uganda             45                9              0
# 180               Ukraine            206              237             45
# 181  United Arab Emirates             16              135              5
# 182        United Kingdom            219              126            195
# 183              Tanzania             36                6              1
# 184                   USA            249              158             84
# 185               Uruguay            115               35            220
# 186            Uzbekistan             25              101              8
# 187               Vanuatu             21               18             11
# 188             Venezuela            333              100              3
# 189               Vietnam            111                2              1
# 190                 Yemen              6                0              0
# 191                Zambia             32               19              4
# 192              Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# 3                            12.4        EU
# 4                             5.9        AF
# 5                             4.9        NA
# 6                             8.3        SA
# 7                             3.8        EU
# 8                            10.4        OC
# 9                             9.7        EU
# 10                            1.3        EU
# 11                            6.3        NA
# 12                            2.0        AS
# 13                            0.0        AS
# 14                            6.3        NA
# 15                           14.4        EU
# 16                           10.5        EU
# 17                            6.8        NA
# 18                            1.1        AF
# 19                            0.4        AS
# 20                            3.8        SA
# 21                            4.6        EU
# 22                            5.4        AF
# 23                            7.2        SA
# 24                            0.6        AS
# 25                           10.3        EU
# 26                            4.3        AF
# 27                            6.3        AF
# 28                            4.0        AF
# 29                            4.0        AF
# ..                            ...       ...
# 163                           5.6        SA
# 164                           4.7        AF
# 165                           7.2        EU
# 166                          10.2        EU
# 167                           1.0        AS
# 168                           0.3        AS
# 169                           6.4        AS
# 170                           3.9        EU
# 171                           0.1        AS
# 172                           1.3        AF
# 173                           1.1        OC
# 174                           6.4        NA
# 175                           1.3        AF
# 176                           1.4        AS
# 177                           2.2        AS
# 178                           1.0        OC
# 179                           8.3        AF
# 180                           8.9        EU
# 181                           2.8        AS
# 182                          10.4        EU
# 183                           5.7        AF
# 184                           8.7        NA
# 185                           6.6        SA
# 186                           2.4        AS
# 187                           0.9        OC
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF
#
# [193 rows x 6 columns]

# %%
drinks = pd.read_csv('https://raw.githubusercontent.com/sinanuozdemir/sfdat28/master/data/drinks.csv', na_filter=False)
drinks.isnull().sum()
# Out:
# country                         0
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# continent                       0
# dtype: int64

# %%
# Selecionando uma coluna
drinks['continent']
drinks.continent
# Out:
# 0      AS
# 1      EU
# 2      AF
# 3      EU
# 4      AF
# 5      NA
# 6      SA
# 7      EU
# 8      OC
# 9      EU
# 10     EU
# 11     NA
# 12     AS
# 13     AS
# 14     NA
# 15     EU
# 16     EU
# 17     NA
# 18     AF
# 19     AS
# 20     SA
# 21     EU
# 22     AF
# 23     SA
# 24     AS
# 25     EU
# 26     AF
# 27     AF
# 28     AF
# 29     AF
#        ..
# 163    SA
# 164    AF
# 165    EU
# 166    EU
# 167    AS
# 168    AS
# 169    AS
# 170    EU
# 171    AS
# 172    AF
# 173    OC
# 174    NA
# 175    AF
# 176    AS
# 177    AS
# 178    OC
# 179    AF
# 180    EU
# 181    AS
# 182    EU
# 183    AF
# 184    NA
# 185    SA
# 186    AS
# 187    OC
# 188    SA
# 189    AS
# 190    AS
# 191    AF
# 192    AF
# Name: continent, Length: 193, dtype: object

# %%
type(drinks.continent)
# Out:
# pandas.core.series.Series

# %%
drinks.continent.describe()
# Out:
# count     193
# unique      6
# top        AF
# freq       53
# Name: continent, dtype: object

# %%
drinks.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# NA    23
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
cols = ['country', 'beer_servings']
drinks[cols].head()
# Out:
#        country  beer_servings
# 0  Afghanistan              0
# 1      Albania             89
# 2      Algeria             25
# 3      Andorra            245
# 4       Angola            217

# %%
#Nova coluna 
drinks['total_servings'] = drinks.beer_servings + drinks.spirit_servings + drinks.wine_servings
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent  total_servings
# 0                           0.0        AS               0
# 1                           4.9        EU             275
# 2                           0.7        AF              39
# 3                          12.4        EU             695
# 4                           5.9        AF             319

# %%
#Filtros lógicos

drinks.continent == 'EU'
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
# 5      False
# 6      False
# 7       True
# 8      False
# 9       True
# 10      True
# 11     False
# 12     False
# 13     False
# 14     False
# 15      True
# 16      True
# 17     False
# 18     False
# 19     False
# 20     False
# 21      True
# 22     False
# 23     False
# 24     False
# 25      True
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 163    False
# 164    False
# 165     True
# 166     True
# 167    False
# 168    False
# 169    False
# 170     True
# 171    False
# 172    False
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180     True
# 181    False
# 182     True
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Name: continent, Length: 193, dtype: bool

# %%
drinks[drinks.continent == 'EU']
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 1               Albania             89              132             54
# 3               Andorra            245              138            312
# 7               Armenia             21              179             11
# 9               Austria            279               75            191
# 10           Azerbaijan             21               46              5
# 15              Belarus            142              373             42
# 16              Belgium            295               84            212
# 21   Bosnia-Herzegovina             76              173              8
# 25             Bulgaria            231              252             94
# 42              Croatia            230               87            254
# 44               Cyprus            192              154            113
# 45       Czech Republic            361              170            134
# 48              Denmark            224               81            278
# 57              Estonia            224              194             59
# 60              Finland            263              133             97
# 61               France            127              151            370
# 64              Georgia             52              100            149
# 65              Germany            346              117            175
# 67               Greece            133              112            218
# 75              Hungary            234              215            185
# 76              Iceland            233               61             78
# 81              Ireland            313              118            165
# 83                Italy             85               42            237
# 93               Latvia            281              216             62
# 98            Lithuania            343              244             56
# 99           Luxembourg            236              133            271
# 105               Malta            149              100            120
# 111              Monaco              0                0              0
# 113          Montenegro             31              114            128
# 120         Netherlands            251               88            190
# 126              Norway            169               71            129
# 135              Poland            343              215             56
# 136            Portugal            194               67            339
# 139             Moldova            109              226             18
# 140             Romania            297              122            167
# 147          San Marino              0                0              0
# 151              Serbia            283              131            127
# 155            Slovakia            196              293            116
# 156            Slovenia            270               51            276
# 160               Spain            284              157            112
# 165              Sweden            152               60            186
# 166         Switzerland            185              100            280
# 170           Macedonia            106               27             86
# 180             Ukraine            206              237             45
# 182      United Kingdom            219              126            195
#
#      total_litres_of_pure_alcohol continent  total_servings
# 1                             4.9        EU             275
# 3                            12.4        EU             695
# 7                             3.8        EU             211
# 9                             9.7        EU             545
# 10                            1.3        EU              72
# 15                           14.4        EU             557
# 16                           10.5        EU             591
# 21                            4.6        EU             257
# 25                           10.3        EU             577
# 42                           10.2        EU             571
# 44                            8.2        EU             459
# 45                           11.8        EU             665
# 48                           10.4        EU             583
# 57                            9.5        EU             477
# 60                           10.0        EU             493
# 61                           11.8        EU             648
# 64                            5.4        EU             301
# 65                           11.3        EU             638
# 67                            8.3        EU             463
# 75                           11.3        EU             634
# 76                            6.6        EU             372
# 81                           11.4        EU             596
# 83                            6.5        EU             364
# 93                           10.5        EU             559
# 98                           12.9        EU             643
# 99                           11.4        EU             640
# 105                           6.6        EU             369
# 111                           0.0        EU               0
# 113                           4.9        EU             273
# 120                           9.4        EU             529
# 126                           6.7        EU             369
# 135                          10.9        EU             614
# 136                          11.0        EU             600
# 139                           6.3        EU             353
# 140                          10.4        EU             586
# 147                           0.0        EU               0
# 151                           9.6        EU             541
# 155                          11.4        EU             605
# 156                          10.6        EU             597
# 160                          10.0        EU             553
# 165                           7.2        EU             398
# 166                          10.2        EU             565
# 170                           3.9        EU             219
# 180                           8.9        EU             488
# 182                          10.4        EU             540

# %%
drinks[['country', 'total_servings']][drinks.continent=='NA'].sort_values(by='total_servings', ascending=False)
# Out:
#                           country  total_servings
# 68                        Grenada             665
# 144                     St. Lucia             557
# 184                           USA             491
# 32                         Canada             462
# 143             St. Kitts & Nevis             431
# 130                        Panama             407
# 17                         Belize             385
# 50                       Dominica             364
# 174             Trinidad & Tobago             360
# 14                       Barbados             352
# 145  St. Vincent & the Grenadines             352
# 51             Dominican Republic             349
# 11                        Bahamas             349
# 73                          Haiti             328
# 109                        Mexico             311
# 5               Antigua & Barbuda             275
# 41                     Costa Rica             247
# 43                           Cuba             235
# 122                     Nicaragua             197
# 84                        Jamaica             188
# 74                       Honduras             169
# 69                      Guatemala             124
# 54                    El Salvador             123

# %%
drinks[drinks.wine_servings > 300][drinks.total_litres_of_pure_alcohol > 12]
# Out:
# /Users/pedroargento/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#    country  beer_servings  spirit_servings  wine_servings  \
# 3  Andorra            245              138            312
#
#    total_litres_of_pure_alcohol continent  total_servings
# 3                          12.4        EU             695

# %%
drinks[(drinks.wine_servings > 300) & (drinks.total_litres_of_pure_alcohol > 12)]
# Out:
#    country  beer_servings  spirit_servings  wine_servings  \
# 3  Andorra            245              138            312
#
#    total_litres_of_pure_alcohol continent  total_servings
# 3                          12.4        EU             695

# %%
# Países que bebem mais cerveja do que vinho
drinks.wine_servings > drinks.beer_servings # is a series of T and F
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
# 5      False
# 6       True
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 163    False
# 164    False
# 165     True
# 166     True
# 167     True
# 168    False
# 169    False
# 170    False
# 171     True
# 172    False
# 173    False
# 174    False
# 175    False
# 176    False
# 177     True
# 178     True
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185     True
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Length: 193, dtype: bool

# %%
drinks.country[drinks.wine_servings > drinks.beer_servings] # is a series of T and F
# Out:
# 3                  Andorra
# 6                Argentina
# 35                   Chile
# 40            Cook Islands
# 42                 Croatia
# 48                 Denmark
# 55       Equatorial Guinea
# 61                  France
# 64                 Georgia
# 67                  Greece
# 83                   Italy
# 92                    Laos
# 94                 Lebanon
# 99              Luxembourg
# 113             Montenegro
# 136               Portugal
# 137                  Qatar
# 148    Sao Tome & Principe
# 156               Slovenia
# 165                 Sweden
# 166            Switzerland
# 167                  Syria
# 171            Timor-Leste
# 177           Turkmenistan
# 178                 Tuvalu
# 185                Uruguay
# Name: country, dtype: object

# %%
# 1. Liste os países que bebem mais spirits do que cerveja

# 2. Quais são os 3 países que mais bebem cerveja?

# 3. Quais são os 3 países que mais bebem cerveja na Europa?

# %%
# Consumo médio de cerveja na américa do norte
drinks.beer_servings[drinks.continent=='NA'].mean()
# Out:
# 145.43478260869566

# %%
drinks.beer_servings[drinks.continent=='EU'].mean()
# Out:
# 193.77777777777777

# %%
#Consolidar Dados
drinks.groupby('continent').continent.count()
# Out:
# continent
# AF    53
# AS    44
# EU    45
# NA    23
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# NA    145.434783
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent').total_servings.apply(lambda x: x.mean())
# Out:
# continent
# AF     94.075472
# AS    106.954545
# EU    468.555556
# NA    335.695652
# OC    183.750000
# SA    352.250000
# Name: total_servings, dtype: float64

# %%
drinks.groupby('continent').total_servings.apply(lambda x: x.std())
# Out:
# continent
# AF    114.040622
# AS    132.630446
# EU    176.921857
# NA    134.437696
# OC    175.450848
# SA     81.923606
# Name: total_servings, dtype: float64

# %%
print(drinks.groupby('continent').total_servings.min())
print(drinks.groupby('continent').total_servings.max())
# Out:
# continent
# AF      0
# AS      0
# EU      0
# NA    123
# OC      0
# SA    216
# Name: total_servings, dtype: int64
# continent
# AF    504
# AS    646
# EU    695
# NA    665
# OC    545
# SA    439
# Name: total_servings, dtype: int64

# %%
drinks.groupby('continent').total_servings.apply(lambda x: x.max() - x.min())
# Out:
# continent
# AF    504
# AS    646
# EU    695
# NA    542
# OC    545
# SA    223
# Name: total_servings, dtype: int64

# %%
drinks.continent.value_counts().plot(kind='bar', title='Países por continente')
plt.xlabel('Continente')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
drinks.groupby('continent').beer_servings.mean().plot(kind='bar')

# %%
drinks.beer_servings.hist(bins=20)

# %%
drinks.beer_servings.hist(by=drinks.continent)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x115334710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1155a4ef0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1156414a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115668a20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x115691f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1156c1550>]],
#       dtype=object)

# %%
drinks.boxplot(column='beer_servings', by='continent')

# %%
drinks.plot(x='beer_servings', y='wine_servings', kind='scatter', alpha=0.3)

# %%
colors = np.where(drinks.continent=='EU', 'r', 'b')
colors
# Out:
# array(['b', 'r', 'b', 'r', 'b', 'b', 'b', 'r', 'b', 'r', 'r', 'b', 'b',
#        'b', 'b', 'r', 'r', 'b', 'b', 'b', 'b', 'r', 'b', 'b', 'b', 'r',
#        'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b',
#        'b', 'b', 'b', 'r', 'b', 'r', 'r', 'b', 'b', 'r', 'b', 'b', 'b',
#        'b', 'b', 'b', 'b', 'b', 'r', 'b', 'b', 'r', 'r', 'b', 'b', 'r',
#        'r', 'b', 'r', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'r', 'r', 'b',
#        'b', 'b', 'b', 'r', 'b', 'r', 'b', 'b', 'b', 'b', 'b', 'b', 'b',
#        'b', 'b', 'r', 'b', 'b', 'b', 'b', 'r', 'r', 'b', 'b', 'b', 'b',
#        'b', 'r', 'b', 'b', 'b', 'b', 'b', 'r', 'b', 'r', 'b', 'b', 'b',
#        'b', 'b', 'b', 'r', 'b', 'b', 'b', 'b', 'b', 'r', 'b', 'b', 'b',
#        'b', 'b', 'b', 'b', 'b', 'r', 'r', 'b', 'b', 'r', 'r', 'b', 'b',
#        'b', 'b', 'b', 'b', 'r', 'b', 'b', 'b', 'r', 'b', 'b', 'b', 'r',
#        'r', 'b', 'b', 'b', 'r', 'b', 'b', 'b', 'b', 'r', 'r', 'b', 'b',
#        'b', 'r', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'r', 'b',
#        'r', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'b'], dtype='<U1')

# %%
drinks.plot(x='beer_servings', y='wine_servings', kind='scatter', c=colors)
